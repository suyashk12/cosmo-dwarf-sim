# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy import optimize
import pandas as pd
import glob
import math
import os

# %%
def fit_error(y, f):
    return np.sum((y-f)**2)

# %%
def fit_func_1(Z, A, sigma):
    
    P = (A/np.sqrt(2*np.pi*sigma**2))*np.exp(-Z**2/(2*sigma**2))
    
    return P

# %%
def fit_func_2(Z, B, alpha):
    
    P = B*np.exp(-alpha*Z)
    
    return P

# %%
def fit_PDF(centers, heights):
    
    # Information about the peak in the numerical PDF
    peak_height = np.max(heights)
    peak_ind = np.where(heights == peak_height)[0][0]
    
    # mu is where the numerical PDF peaks
    mu = centers[peak_ind]
 
    # Recentering so that peak is at z = 0
    del_centers = centers - mu
    gauss_centers = del_centers[0:peak_ind+1]
    gauss_heights = heights[0:peak_ind+1]
                
    fit = np.zeros(len(centers))
    fit_err = np.inf
    fit_params = np.zeros(5)
    
    for i in range(0, len(fit_params)):
        fit_params[i] = float('nan')
    
    try:
        
        # Estimating sigma using FWHM
        sigma = 0

        for i in range(0, len(gauss_centers)):
            if(heights[i] >= peak_height/2):
                sigma = (-gauss_centers[i])/np.sqrt(2*np.log(2))
                break

        # Estimating A accordingly, by using the peak height
        A = np.sqrt(2*np.pi*sigma**2)*peak_height

        # First fit a Gaussian

        guess_gauss_params = np.array([A, sigma])
        
        gauss_bounds = ([0, 0], [np.max(heights), np.max(np.abs(del_centers))])

        fit_gauss_params, fit_gauss_covar = optimize.curve_fit(fit_func_1, gauss_centers, gauss_heights,
                                                               p0 = guess_gauss_params, 
                                                               bounds = gauss_bounds, method = 'trf')

                
        fit_params[0] = fit_gauss_params[0]
        fit_params[1] = mu
        fit_params[2] = fit_gauss_params[1]

        fit = fit_func_1(del_centers, *fit_gauss_params)
        fit_err = fit_error(heights, fit)

        # See if an exponential decay tail exists and is a better fit

        for i in range(peak_ind, len(centers)):

            try:

                v_T = centers[i]

                exp_centers = del_centers[i:] - del_centers[i]

                exp_heights = heights[i:]
                init_height = exp_heights[0]

                # Estimating alpha using half-life decay
                alpha = 0

                for j in range(0, len(exp_centers)):
                    if(exp_heights[j] <= init_height/2):
                        alpha = np.log(2)/(exp_centers[j])
                        break

                B = (fit_params[0]*np.exp(alpha*v_T))/np.sqrt(2*np.pi*fit_params[2]**2)*np.exp(-(v_T-mu)**2/(2*fit_params[2]**2))

                guess_exp_params = np.array([B, alpha])
                
                exp_bounds = ([0, 0], [np.max(heights), np.inf])

                fit_exp_params, fit_exp_covar = optimize.curve_fit(fit_func_2, exp_centers, exp_heights,
                                                                   p0 = guess_exp_params, 
                                                                   bounds = exp_bounds, method = 'trf')

                gauss_fit = fit_func_1(del_centers[:i], *fit_gauss_params)
                exp_fit = fit_func_2(exp_centers, *fit_exp_params)
                curr_fit = np.concatenate([gauss_fit, exp_fit])
                curr_err = fit_error(heights, curr_fit)

                if(curr_err < fit_err):
                    fit = curr_fit
                    fit_err = curr_err
                    fit_params[3] = fit_exp_params[1]
                    fit_params[4] = v_T

            except:
                continue
                
    except:
        
        pass
    
    return fit, fit_params

# %%
# Specifying simulation directory and the directory to save results in
wdir = str(input('Enter simulation directory path: '))

# Specifying a snapshot for temporal analysis
sdir = wdir + 'temporal_analysis/'
# Out:
# Enter simulation directory path: /Users/thepoetoftwilight/Documents/CASSI2020/CASSI2020-Results/m10q_res250/

# %%
# Get all rendered indices

rendered_df = pd.read_csv(sdir + 'rendered_snap_stats.csv')
rendered_indices = rendered_df['snap'].to_list()
redshifts = rendered_df['redshift'].to_list()
num_snaps = len(rendered_indices)

fitted_df = rendered_df

# Get rendered metals

metal_df = pd.read_csv((sdir + 'metal_list.csv'))
metals = metal_df['metals'].to_list()

# Create a list of paths for all metals
spath_metals = {}

for m in metals:
    spath_metals[m] = sdir + m + '/'

# %%
# Get statistics for all snapshots
As = {}
mus = {}
sigmas = {}
alphas = {}
z_Ts = {}

for m in metals:
    As[m] = []
    mus[m] = []
    sigmas[m] = []
    alphas[m] = []
    z_Ts[m] = []
    
for i in range(0, num_snaps):
    
    snap_index = rendered_indices[i]
    redshift = redshifts[i]

    print('Processing snapshot {} ... \n'.format(str(snap_index)))

    snap_info = {}

    for m in metals:
        snap_info[m] = {}

    
    # Get numerical data for all metals
    for m in metals:

        print('Processing {} ...'.format(m.title()))

        # Load the numerical PDF and normalize

        num_df = pd.read_csv(spath_metals[m] +'data/num/' + str(snap_index) + '-num_' + m + '_data.csv')
        centers = np.array(num_df['abundance'].to_list())
        heights = np.array(num_df['num_val'].to_list())

        mass_norm = np.max(heights)
        heights /= mass_norm

        # Compute the fitted PDF

        fit, fit_params = fit_PDF(centers, heights)

        print(fit_params)

        # Rescaling range to achieve desired normalization

        heights *= mass_norm
        fit *= mass_norm
        fit_params[0] *= mass_norm

        # Appending fitted data
        snap_info[m]['centers'] = centers
        snap_info[m]['heights'] = heights
        snap_info[m]['fit'] = fit
        snap_info[m]['fit_params'] = fit_params


    for m in metals:

        # Saving the fitted data

        datafile =  str(snap_index) + '-fit_' + m + '_data' + '.csv'

        centers = snap_info[m]['centers']
        heights = snap_info[m]['heights']
        fit = snap_info[m]['fit']
        fit_params = snap_info[m]['fit_params']

        As[m].append(fit_params[0])
        mus[m].append(fit_params[1])
        sigmas[m].append(fit_params[2])
        z_Ts[m].append(fit_params[3])
        alphas[m].append(fit_params[4])

        fit_dict = {'abundance': centers, 'fit_val': fit}
        fit_df = pd.DataFrame(fit_dict)
        fit_df.to_csv(spath_metals[m] + 'data/fit/' + datafile)

        print('Completed rendering for ' + m.title()) 


    print()
    print('Completed fitting for snapshot ' + str(snap_index) + '\n')
# Out:
# Processing snapshot 110 ...
#
# Processing C ...
# [ 0.98790148 -2.075       0.43193218  6.11331408 -1.925     ]
# Processing N ...
# /Users/thepoetoftwilight/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/thepoetoftwilight/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in multiply
#   This is separate from the ipykernel package so we can avoid doing imports until
# [ 0.95742809 -2.575       0.40330139  5.20719401 -2.225     ]
# Processing O ...
# [ 0.9825926  -1.775       0.4461167   6.58927589 -1.625     ]
# Processing Ne ...
# [ 0.94802957 -1.725       0.44169831  6.43999754 -1.575     ]
# Processing Mg ...
# [ 0.84667219 -2.025       0.42864715  5.65961093 -1.875     ]
# Processing Si ...
# [ 0.90479728 -1.975       0.42709253  5.49721449 -1.875     ]
# Processing S ...
# [ 0.90424875 -2.025       0.42496028  6.73637323 -1.825     ]
# Processing Ca ...
# [ 0.94532737 -2.275       0.43041107  6.45461928 -2.125     ]
# Processing Fe ...
# [ 0.91752283 -2.325       0.41252136  5.68799768 -2.225     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 110
#
# Processing snapshot 111 ...
#
# Processing C ...
# [ 0.72124955 -2.025       0.32853484  7.6788972  -1.825     ]
# Processing N ...
# [ 0.88042226 -2.425       0.38507581  5.58088472 -2.225     ]
# Processing O ...
# [ 0.74860449 -1.725       0.33112269  6.73256132 -1.625     ]
# Processing Ne ...
# [ 0.72236426 -1.675       0.32502037  7.13789721 -1.525     ]
# Processing Mg ...
# [ 0.70319335 -1.925       0.32056784  7.09703999 -1.775     ]
# Processing Si ...
# [ 0.67640946 -1.925       0.31101712  6.91028666 -1.775     ]
# Processing S ...
# [ 0.68440344 -1.975       0.311572    6.89806638 -1.825     ]
# Processing Ca ...
# [ 0.63936665 -2.275       0.30399393  6.03476528 -2.175     ]
# Processing Fe ...
# [ 0.61427038 -2.325       0.2908251   5.85855092 -2.225     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 111
#
# Processing snapshot 112 ...
#
# Processing C ...
# [ 0.65833738 -1.925       0.29471038  8.17146488 -1.775     ]
# Processing N ...
# [ 0.88833418 -2.275       0.37897143  6.12222979 -2.175     ]
# Processing O ...
# [ 0.5679434  -1.675       0.25563411  7.55394801 -1.525     ]
# Processing Ne ...
# [ 0.64304779 -1.575       0.27250262  7.24409486 -1.475     ]
# Processing Mg ...
# [ 0.62270258 -1.825       0.26758995  7.10074328 -1.725     ]
# Processing Si ...
# [ 0.60370163 -1.825       0.26200965  7.12559969 -1.725     ]
# Processing S ...
# [ 0.61444975 -1.875       0.26373115  7.31450291 -1.775     ]
# Processing Ca ...
# [ 0.56168543 -2.175       0.25137277  7.76509586 -2.025     ]
# Processing Fe ...
# [ 0.5645573  -2.225       0.24785936  7.00231287 -2.125     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 112
#
# Processing snapshot 113 ...
#
# Processing C ...
# [ 0.91371572 -1.925       0.42527356  6.47851426 -1.825     ]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [ 0.90972275 -1.575       0.38321374  6.83364357 -1.475     ]
# Processing Ne ...
# [ 0.87351867 -1.525       0.3753252   6.5854051  -1.425     ]
# Processing Mg ...
# [ 0.8428017  -1.775       0.37009937  6.48584013 -1.675     ]
# Processing Si ...
# [ 0.74257194 -1.825       0.34794975  7.33614172 -1.625     ]
# Processing S ...
# [ 0.76574485 -1.875       0.34989213  5.8039692  -1.775     ]
# Processing Ca ...
# [ 0.80729724 -2.125       0.35837421  7.16522866 -1.975     ]
# Processing Fe ...
# [ 0.71457255 -2.225       0.3407364   6.99074916 -2.025     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 113
#
# Processing snapshot 114 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [ 2.50662827e-10 -1.42500000e+00  1.00000000e-10             nan
#              nan]
# Processing Ne ...
# [ 2.50662827e-10 -1.37500000e+00  1.00000000e-10             nan
#              nan]
# Processing Mg ...
# [ 2.50662827e-10 -1.57500000e+00  1.00000000e-10             nan
#              nan]
# Processing Si ...
# [ 2.50662827e-10 -1.57500000e+00  1.00000000e-10             nan
#              nan]
# Processing S ...
# [ 2.50662827e-10 -1.62500000e+00  1.00000000e-10             nan
#              nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 114
#
# Processing snapshot 116 ...
#
# Processing C ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10             nan
#              nan]
# Processing N ...
# [ 2.50662827e-10 -1.32500000e+00  1.00000000e-10             nan
#              nan]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 116
#
# Processing snapshot 118 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [ 0.74810023 -2.125       0.35281388  6.42728279 -1.675     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [ 0.29678329 -2.825       0.13939772  0.87443015 -2.575     ]
# Processing Ca ...
# [ 0.29211721 -3.025       0.1454767   1.16291209 -2.775     ]
# Processing Fe ...
# [ 0.33998572 -2.675       0.13433403  2.65550679 -2.375     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 118
#
# Processing snapshot 119 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 119
#
# Processing snapshot 120 ...
#
# Processing C ...
# [ 1.         -2.025       0.43667493  5.29392868 -1.725     ]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 120
#
# Processing snapshot 121 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 121
#
# Processing snapshot 122 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [ 0.54708234 -3.225       0.20410632  1.31449919 -2.925     ]
# Processing O ...
# [ 0.517543   -2.875       0.21964436  0.90260934 -2.675     ]
# Processing Ne ...
# [ 0.56238839 -2.775       0.23416804  0.95512743 -2.575     ]
# Processing Mg ...
# [ 0.52033372 -3.025       0.21629516  0.95091576 -2.825     ]
# Processing Si ...
# [ 0.56614726 -2.975       0.22827886  1.00929695 -2.775     ]
# Processing S ...
# [ 0.48226638 -3.025       0.19782827  1.07506568 -2.825     ]
# Processing Ca ...
# [ 0.43019056 -3.275       0.17368409  1.0992579  -3.125     ]
# Processing Fe ...
# [ 0.45751438 -3.325       0.18305533  1.07839771 -3.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 122
#
# Processing snapshot 123 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [ 0.57337463 -3.225       0.21242822  1.13303332 -2.875     ]
# Processing O ...
# [ 0.56682251 -2.875       0.24145213  0.97140037 -2.625     ]
# Processing Ne ...
# [ 0.62374038 -2.775       0.25878366  1.02107982 -2.475     ]
# Processing Mg ...
# [ 0.5629655  -3.025       0.23735088  0.99860833 -2.775     ]
# Processing Si ...
# [ 0.63273139 -2.975       0.25092196  1.054479   -2.675     ]
# Processing S ...
# [ 0.55199188 -3.025       0.21956152  0.99752475 -2.825     ]
# Processing Ca ...
# [ 0.48765844 -3.275       0.19163911  1.04843024 -3.075     ]
# Processing Fe ...
# [ 0.50663308 -3.325       0.19796998  1.04778266 -3.125     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 123
#
# Processing snapshot 124 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 124
#
# Processing snapshot 125 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [ 0.37200841 -3.425       0.15573147  0.80288585 -3.275     ]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 125
#
# Processing snapshot 126 ...
#
# Processing C ...
# [ 1.         -1.725       0.44484497  5.01995922 -1.575     ]
# Processing N ...
# [ 1.         -1.975       0.43519272  4.72582925 -1.775     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 126
#
# Processing snapshot 127 ...
#
# Processing C ...
# [ 1.         -1.725       0.42433145  4.70758583 -1.675     ]
# Processing N ...
# [ 1.         -2.075       0.42645929  5.26291958 -1.775     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 127
#
# Processing snapshot 128 ...
#
# Processing C ...
# [ 0.88734433 -1.825       0.39672609  5.31458063 -1.625     ]
# Processing N ...
# [ 1.         -2.025       0.41706224  4.54728514 -1.875     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 128
#
# Processing snapshot 129 ...
#
# Processing C ...
# [ 0.86596777 -1.875       0.39637309  5.7678911  -1.625     ]
# Processing N ...
# [ 0.86637174 -2.175       0.39855848  4.0611071  -1.975     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 129
#
# Processing snapshot 130 ...
#
# Processing C ...
# [ 0.80349363 -1.875       0.37765757  6.36217821 -1.575     ]
# Processing N ...
# [ 0.90498557 -2.125       0.40143974  6.03636305 -1.775     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 130
#
# Processing snapshot 131 ...
#
# Processing C ...
# [ 0.77189434 -1.875       0.35448129  6.24689863 -1.625     ]
# Processing N ...
# [ 1.         -2.025       0.41654494  5.15032249 -1.875     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 131
#
# Processing snapshot 132 ...
#
# Processing C ...
# [ 0.69195864 -1.825       0.30887056  7.12038215 -1.625     ]
# Processing N ...
# [ 0.90073513 -2.025       0.37884768  5.89318106 -1.875     ]
# Processing O ...
# [ 1.         -1.775       0.44237432  6.08107788 -1.675     ]
# Processing Ne ...
# [ 1.         -1.725       0.45029371  6.5283879  -1.575     ]
# Processing Mg ...
# [ 1.         -1.975       0.44928932  6.40950318 -1.825     ]
# Processing Si ...
# [ 0.98850312 -1.975       0.446897    6.96797009 -1.775     ]
# Processing S ...
# [ 0.99212758 -2.025       0.44662897  6.43058603 -1.875     ]
# Processing Ca ...
# [ 1.         -2.275       0.44434334  6.91318331 -2.125     ]
# Processing Fe ...
# [ 1.         -2.325       0.43103098  5.94181441 -2.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 132
#
# Processing snapshot 133 ...
#
# Processing C ...
# [ 0.6918951  -1.825       0.32094672  7.40319566 -1.625     ]
# Processing N ...
# [ 0.95453619 -2.025       0.39871934  6.16573256 -1.875     ]
# Processing O ...
# [ 0.93522408 -1.775       0.43817641  6.91823771 -1.575     ]
# Processing Ne ...
# [ 0.90509659 -1.725       0.43520928  6.89480666 -1.525     ]
# Processing Mg ...
# [ 0.97678985 -1.925       0.44568775  6.88623165 -1.775     ]
# Processing Si ...
# [ 0.9351431  -1.925       0.43582366  6.74950026 -1.775     ]
# Processing S ...
# [ 0.94482942 -1.975       0.43554634  6.80628577 -1.825     ]
# Processing Ca ...
# [ 0.9110459  -2.275       0.42680821  7.00441515 -2.075     ]
# Processing Fe ...
# [ 0.84782578 -2.325       0.40707178  5.44869657 -2.225     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 133
#
# Processing snapshot 134 ...
#
# Processing C ...
# [ 0.90762863 -1.825       0.40652613  7.99543197 -1.625     ]
# Processing N ...
# [ 1.         -2.075       0.42393317  6.49039119 -1.875     ]
# Processing O ...
# [ 1.         -1.825       0.50151781  5.64291901 -1.675     ]
# Processing Ne ...
# [ 1.         -1.725       0.49341858  6.76478213 -1.525     ]
# Processing Mg ...
# [ 1.         -1.925       0.47629049  6.71759121 -1.775     ]
# Processing Si ...
# [ 1.         -1.925       0.47870135  6.62528508 -1.775     ]
# Processing S ...
# [ 1.         -1.975       0.47431234  6.65419065 -1.825     ]
# Processing Ca ...
# [ 1.         -2.275       0.48031944  6.78908508 -2.075     ]
# Processing Fe ...
# [ 1.         -2.275       0.46138876  5.6540292  -2.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 134
#
# Processing snapshot 135 ...
#
# Processing C ...
# [ 1.         -1.825       0.43704747  7.00750996 -1.675     ]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [ 1.         -1.775       0.49451405  5.8606712  -1.675     ]
# Processing Ne ...
# [ 1.         -1.725       0.50500837  6.3434706  -1.575     ]
# Processing Mg ...
# [ 1.         -1.925       0.49016628  6.28621368 -1.825     ]
# Processing Si ...
# [ 1.         -1.925       0.48880579  6.06537872 -1.825     ]
# Processing S ...
# [ 1.         -1.975       0.48879498  6.08327073 -1.875     ]
# Processing Ca ...
# [ 1.         -2.275       0.48994894  5.79548035 -2.175     ]
# Processing Fe ...
# [ 1.         -2.275       0.47815067  6.03712798 -2.125     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 135
#
# Processing snapshot 136 ...
#
# Processing C ...
# [ 0.91786385 -1.875       0.44062082  7.82876139 -1.625     ]
# Processing N ...
# [ 1.         -2.175       0.4550238   6.40003603 -1.875     ]
# Processing O ...
# [ 1.         -1.825       0.52052351  4.66806719 -1.725     ]
# Processing Ne ...
# [ 1.         -1.675       0.49942492  6.68068387 -1.525     ]
# Processing Mg ...
# [ 1.         -1.975       0.51645703  5.38300168 -1.875     ]
# Processing Si ...
# [ 1.         -1.975       0.51985477  5.04954215 -1.875     ]
# Processing S ...
# [ 1.         -1.975       0.50010676  6.15555009 -1.875     ]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [ 1.         -2.325       0.50191965  4.35356656 -2.275     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 136
#
# Processing snapshot 137 ...
#
# Processing C ...
# [ 0.91129594 -1.875       0.424802    6.88665255 -1.675     ]
# Processing N ...
# [nan nan nan nan nan]
# Processing O ...
# [ 1.         -1.775       0.49223241  5.99200143 -1.675     ]
# Processing Ne ...
# [ 1.         -1.725       0.49926813  6.76566323 -1.525     ]
# Processing Mg ...
# [ 1.         -1.975       0.49760971  6.41369671 -1.825     ]
# Processing Si ...
# [ 1.         -1.975       0.50181303  6.19005415 -1.825     ]
# Processing S ...
# [ 1.         -1.975       0.48572482  6.7322078  -1.825     ]
# Processing Ca ...
# [ 1.         -2.275       0.48524878  6.56845797 -2.125     ]
# Processing Fe ...
# [ 1.         -2.325       0.48242138  5.4082072  -2.225     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 137
#
# Processing snapshot 138 ...
#
# Processing C ...
# [ 0.9244893  -1.875       0.42035343  7.0888772  -1.675     ]
# Processing N ...
# [ 1.         -2.175       0.42940676  6.05631175 -1.925     ]
# Processing O ...
# [nan nan nan nan nan]
# Processing Ne ...
# [nan nan nan nan nan]
# Processing Mg ...
# [nan nan nan nan nan]
# Processing Si ...
# [nan nan nan nan nan]
# Processing S ...
# [nan nan nan nan nan]
# Processing Ca ...
# [nan nan nan nan nan]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 138
#
# Processing snapshot 139 ...
#
# Processing C ...
# [ 0.77587669 -1.875       0.36440957  7.65162684 -1.675     ]
# Processing N ...
# [ 0.98168024 -2.125       0.41164086  6.45624132 -1.925     ]
# Processing O ...
# [ 0.94909117 -1.775       0.43350366  7.20214799 -1.625     ]
# Processing Ne ...
# [ 0.89935983 -1.725       0.4278378   7.01034838 -1.575     ]
# Processing Mg ...
# [ 0.88298386 -1.975       0.42349655  7.51817938 -1.775     ]
# Processing Si ...
# [ 0.94317893 -1.925       0.4304507   7.40223585 -1.775     ]
# Processing S ...
# [ 0.94480335 -1.975       0.42823895  6.76775925 -1.875     ]
# Processing Ca ...
# [ 0.89125358 -2.275       0.41558828  7.0955308  -2.125     ]
# Processing Fe ...
# [ 0.8399607  -2.325       0.39717827  6.65084304 -2.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 139
#
# Processing snapshot 140 ...
#
# Processing C ...
# [ 0.77079386 -1.825       0.3428292   8.2757099  -1.675     ]
# Processing N ...
# [ 0.87718935 -2.125       0.3792381   6.98568799 -1.925     ]
# Processing O ...
# [ 0.85084165 -1.725       0.38060541  6.95000259 -1.625     ]
# Processing Ne ...
# [ 0.81186241 -1.675       0.37415309  7.22698877 -1.525     ]
# Processing Mg ...
# [ 0.78834591 -1.925       0.37059467  7.22700306 -1.775     ]
# Processing Si ...
# [ 0.76094667 -1.925       0.36387746  7.15764389 -1.775     ]
# Processing S ...
# [ 0.76510519 -1.975       0.36260103  7.2121883  -1.825     ]
# Processing Ca ...
# [ 0.72854104 -2.275       0.35432088  6.21496857 -2.175     ]
# Processing Fe ...
# [ 0.75721681 -2.275       0.35065744  6.88096391 -2.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 140
#
# Processing snapshot 141 ...
#
# Processing C ...
# [ 0.72468387 -1.825       0.33395193  8.58440395 -1.675     ]
# Processing N ...
# [ 0.96100066 -2.075       0.40446217  6.73706083 -1.975     ]
# Processing O ...
# [ 0.72976944 -1.725       0.34726258  7.20217742 -1.575     ]
# Processing Ne ...
# [ 0.70349557 -1.675       0.34470972  7.70597849 -1.475     ]
# Processing Mg ...
# [ 0.69244415 -1.925       0.34284847  6.10464759 -1.825     ]
# Processing Si ...
# [ 0.74714584 -1.875       0.34622726  7.49230082 -1.725     ]
# Processing S ...
# [ 0.66934395 -1.975       0.33510014  6.07886705 -1.875     ]
# Processing Ca ...
# [ 0.70599575 -2.225       0.33655443  7.32513335 -2.075     ]
# Processing Fe ...
# [ 0.66094466 -2.275       0.32366553  6.50235882 -2.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 141
#
# Processing snapshot 142 ...
#
# Processing C ...
# [ 0.72856791 -1.825       0.32050942  8.76791127 -1.675     ]
# Processing N ...
# [ 0.8672164  -2.125       0.37140644  7.75436942 -1.925     ]
# Processing O ...
# [ 0.76698545 -1.675       0.33271386  7.04723915 -1.575     ]
# Processing Ne ...
# [ 0.7302015  -1.625       0.32419458  7.76493663 -1.475     ]
# Processing Mg ...
# [ 0.71405664 -1.875       0.32077473  7.60304495 -1.725     ]
# Processing Si ...
# [ 0.69449651 -1.875       0.31425036  7.33548373 -1.725     ]
# Processing S ...
# [ 0.70013991 -1.925       0.31413961  7.39930737 -1.775     ]
# Processing Ca ...
# [ 0.73937461 -2.175       0.32342805  7.08045536 -2.075     ]
# Processing Fe ...
# [ 0.70794514 -2.225       0.31243388  6.64563516 -2.125     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 142
#
# Processing snapshot 143 ...
#
# Processing C ...
# [ 0.79905779 -1.775       0.34506125  8.74723894 -1.675     ]
# Processing N ...
# [ 0.85648203 -2.125       0.38339915  8.0958297  -1.925     ]
# Processing O ...
# [ 0.73061825 -1.675       0.32467254  7.48587823 -1.525     ]
# Processing Ne ...
# [ 0.70014837 -1.625       0.31846009  7.43629223 -1.475     ]
# Processing Mg ...
# [ 0.69142123 -1.875       0.31577972  7.80669493 -1.675     ]
# Processing Si ...
# [ 0.65537047 -1.875       0.30915982  6.09145281 -1.775     ]
# Processing S ...
# [ 0.75226323 -1.875       0.3259766   6.98398847 -1.775     ]
# Processing Ca ...
# [ 0.69417411 -2.175       0.3144226   7.18424485 -2.025     ]
# Processing Fe ...
# [ 0.64891021 -2.225       0.3029115   6.35598631 -2.075     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 143
#
# Processing snapshot 144 ...
#
# Processing C ...
# [ 0.83854612 -1.775       0.35231209  8.82716169 -1.675     ]
# Processing N ...
# [ 0.88317869 -2.125       0.38126505  7.00773205 -1.975     ]
# Processing O ...
# [ 0.65109624 -1.725       0.31417721  6.02754549 -1.625     ]
# Processing Ne ...
# [ 0.69927348 -1.625       0.32222441  7.50930001 -1.475     ]
# Processing Mg ...
# [ 0.6842613  -1.875       0.31846364  7.4368152  -1.725     ]
# Processing Si ...
# [ 0.653898  -1.875      0.3097892  7.8507713 -1.675    ]
# Processing S ...
# [ 0.66256962 -1.925       0.30928562  7.92468005 -1.725     ]
# Processing Ca ...
# [ 0.69961526 -2.175       0.31560153  6.76853305 -2.075     ]
# Processing Fe ...
# [ 0.65709862 -2.225       0.30196703  6.31565797 -2.125     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 144
#
# Processing snapshot 145 ...
#
# Processing C ...
# [ 0.89224751 -1.775       0.3750729   8.53430545 -1.675     ]
# Processing N ...
# [ 0.92098382 -2.125       0.40036762  7.04301302 -1.975     ]
# Processing O ...
# [ 0.79159153 -1.675       0.35509417  7.90891037 -1.525     ]
# Processing Ne ...
# [ 0.76314005 -1.625       0.35015458  7.63356137 -1.475     ]
# Processing Mg ...
# [ 0.7480786  -1.875       0.34718121  7.52580976 -1.725     ]
# Processing Si ...
# [ 0.72053601 -1.875       0.33817786  7.99165058 -1.675     ]
# Processing S ...
# [ 0.72133641 -1.925       0.33622065  7.33832942 -1.775     ]
# Processing Ca ...
# [ 0.75402313 -2.175       0.34131167  6.99751784 -2.075     ]
# Processing Fe ...
# [ 0.71649747 -2.225       0.32611599  7.0475286  -2.075     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 145
#
# Processing snapshot 146 ...
#
# Processing C ...
# [ 0.76709106 -1.825       0.33900991  8.74890261 -1.675     ]
# Processing N ...
# [ 0.91819929 -2.125       0.38474213  7.19964928 -1.975     ]
# Processing O ...
# [ 0.76315105 -1.675       0.34008816  7.2622346  -1.575     ]
# Processing Ne ...
# [ 0.73600894 -1.625       0.33458481  7.86005066 -1.475     ]
# Processing Mg ...
# [ 0.7228697  -1.875       0.33172974  7.740367   -1.725     ]
# Processing Si ...
# [ 0.7872899  -1.825       0.34037264  7.43127628 -1.725     ]
# Processing S ...
# [ 0.69812104 -1.925       0.32120923  7.52798364 -1.775     ]
# Processing Ca ...
# [ 0.7354447  -2.175       0.32753896  7.2519594  -2.075     ]
# Processing Fe ...
# [ 0.6931523  -2.225       0.31015494  6.83465655 -2.125     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 146
#
# Processing snapshot 147 ...
#
# Processing C ...
# [ 0.73761128 -1.825       0.32358046  8.6955615  -1.675     ]
# Processing N ...
# [ 0.87998926 -2.125       0.3685704   7.16920111 -1.975     ]
# Processing O ...
# [ 0.65226699 -1.725       0.31209865  6.35706468 -1.625     ]
# Processing Ne ...
# [ 0.71173122 -1.625       0.32067123  7.95132924 -1.475     ]
# Processing Mg ...
# [ 0.6953352  -1.875       0.31774345  7.75216058 -1.725     ]
# Processing Si ...
# [ 0.75841323 -1.825       0.32643739  7.60393795 -1.725     ]
# Processing S ...
# [ 0.67009538 -1.925       0.30683925  7.73895461 -1.775     ]
# Processing Ca ...
# [ 0.71624233 -2.175       0.31439213  7.28501239 -2.075     ]
# Processing Fe ...
# [ 0.66495713 -2.225       0.2963329   7.27264616 -2.075     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 147
#
# Processing snapshot 148 ...
#
# Processing C ...
# [ 0.67157571 -1.825       0.29694416  9.12261177 -1.675     ]
# Processing N ...
# [ 0.79495518 -2.125       0.34173081  7.64083305 -1.975     ]
# Processing O ...
# [ 0.67687196 -1.675       0.29941704  7.64719574 -1.575     ]
# Processing Ne ...
# [ 0.63492493 -1.625       0.29202731  8.24719322 -1.475     ]
# Processing Mg ...
# [ 0.61917372 -1.875       0.28935391  8.05651181 -1.725     ]
# Processing Si ...
# [ 0.58635883 -1.875       0.28072904  8.70724489 -1.675     ]
# Processing S ...
# [ 0.59191465 -1.925       0.27972239  6.98762916 -1.825     ]
# Processing Ca ...
# [ 0.6435341  -2.175       0.2870643   7.49345141 -2.075     ]
# Processing Fe ...
# [ 0.59766656 -2.225       0.26899858  7.55932966 -2.075     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 148
#
# Processing snapshot 149 ...
#
# Processing C ...
# [ 0.59029868 -1.775       0.26392907 10.22683452 -1.625     ]
# Processing N ...
# [ 0.69921088 -2.075       0.31526562  8.71413117 -1.925     ]
# Processing O ...
# [ 0.58181294 -1.625       0.2546558   7.39519057 -1.525     ]
# Processing Ne ...
# [ 0.53604222 -1.575       0.246294    7.79774455 -1.425     ]
# Processing Mg ...
# [ 0.51956754 -1.825       0.24239772  7.00101151 -1.725     ]
# Processing Si ...
# [ 0.50069001 -1.825       0.23452525  6.81967742 -1.725     ]
# Processing S ...
# [ 0.49912684 -1.875       0.23392927  6.97377832 -1.775     ]
# Processing Ca ...
# [ 0.5514629  -2.125       0.24413003  7.46537145 -2.025     ]
# Processing Fe ...
# [ 0.51277814 -2.175       0.22876867  7.46587388 -2.025     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 149
#
# Processing snapshot 150 ...
#
# Processing C ...
# [ 0.63902164 -1.725       0.28753803  9.59109411 -1.575     ]
# Processing N ...
# [ 0.75563238 -2.025       0.33573656  7.77076841 -1.925     ]
# Processing O ...
# [ 0.59479776 -1.575       0.26129284  7.42687149 -1.425     ]
# Processing Ne ...
# [ 0.56670778 -1.525       0.2551462   7.7810498  -1.325     ]
# Processing Mg ...
# [ 0.65210675 -1.725       0.27479349  7.08570195 -1.625     ]
# Processing Si ...
# [ 0.62242829 -1.725       0.2655751   7.01455123 -1.625     ]
# Processing S ...
# [ 0.5290743  -1.825       0.2448009   6.28304117 -1.725     ]
# Processing Ca ...
# [ 0.5743055  -2.075       0.25343161  7.61409292 -1.925     ]
# Processing Fe ...
# [ 0.52890381 -2.125       0.24012312  7.45605744 -1.975     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 150
#
# Processing snapshot 151 ...
#
# Processing C ...
# [ 0.61578753 -1.675       0.25715464  9.0849879  -1.575     ]
# Processing N ...
# [ 0.68475751 -2.025       0.29890267  9.30869292 -1.925     ]
# Processing O ...
# [ 0.54017342 -1.475       0.2280731   6.55823272 -1.325     ]
# Processing Ne ...
# [ 0.5026909  -1.425       0.21864673  7.74369907 -1.175     ]
# Processing Mg ...
# [ 0.58951167 -1.625       0.24061209  6.23005345 -1.525     ]
# Processing Si ...
# [ 0.46595706 -1.675       0.20757969  5.44161264 -1.575     ]
# Processing S ...
# [ 0.56698892 -1.675       0.23418095  6.30026689 -1.575     ]
# Processing Ca ...
# [ 0.52221134 -1.975       0.22186855  6.71922542 -1.825     ]
# Processing Fe ...
# [ 0.48239125 -2.025       0.20853416  7.20689027 -1.825     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 151
#
# Processing snapshot 172 ...
#
# Processing C ...
# [nan nan nan nan nan]
# Processing N ...
# [ 2.50662827e-10 -1.37500000e+00  1.00000000e-10  7.72575927e-01
#  -1.27500000e+00]
# Processing O ...
# [  0.24957561  -1.525        0.19857581 160.58937059  -1.275     ]
# Processing Ne ...
# [  0.22698978  -1.475        0.21595575 180.47852672  -1.225     ]
# Processing Mg ...
# [ 8.33414744e-02 -1.67500000e+00  3.32367627e-02  1.75540585e+02
#  -1.47500000e+00]
# Processing Si ...
# [ 0.32413158 -1.475       0.21475953 19.19666029 -1.475     ]
# Processing S ...
# [  0.46618849  -1.475        0.37059041 298.63830674  -1.475     ]
# Processing Ca ...
# [  0.29649474  -1.775        0.38643581 144.4008989   -1.775     ]
# Processing Fe ...
# [nan nan nan nan nan]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 172
#
# Processing snapshot 173 ...
#
# Processing C ...
# [ 0.62398363 -1.325       0.29738098  1.66683819 -1.225     ]
# Processing N ...
# [ 0.54667621 -1.525       0.30319876  1.68659079 -1.475     ]
# Processing O ...
# /Users/thepoetoftwilight/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:74: RuntimeWarning: invalid value encountered in double_scalars
# [ 2.50662827e-10 -1.67500000e+00  1.00000000e-10  4.14403869e+00
#  -1.62500000e+00]
# Processing Ne ...
# [ 0.17472446 -1.625       0.07966748  4.09906594 -1.575     ]
# Processing Mg ...
# [ 0.30538788 -1.775       0.14723248  4.45772681 -1.575     ]
# Processing Si ...
# [ 0.31036341 -1.725       0.14013777  8.2997108  -1.575     ]
# Processing S ...
# [ 0.39426375 -1.725       0.19059361  5.49537114 -1.725     ]
# Processing Ca ...
# [ 0.41197974 -1.975       0.20312397  4.50063983 -1.925     ]
# Processing Fe ...
# [ 0.36742793 -2.025       0.18308591  4.89480454 -1.725     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 173
#
# Processing snapshot 174 ...
#
# Processing C ...
# [ 0.33842408 -1.575       0.18024461  2.09395459 -1.425     ]
# Processing N ...
# [ 0.87018219 -1.475       0.3737414   2.69751331 -1.475     ]
# Processing O ...
# [ 0.94540171 -1.525       0.49413504  5.32276954 -1.525     ]
# Processing Ne ...
# [ 0.87481154 -1.525       0.51692529  3.77299933 -1.525     ]
# Processing Mg ...
# [ 0.89920831 -1.725       0.49450914  4.60849771 -1.725     ]
# Processing Si ...
# [ 0.78699215 -1.725       0.48493249  3.73402979 -1.725     ]
# Processing S ...
# [ 0.81294047 -1.775       0.49085233  3.53620647 -1.775     ]
# Processing Ca ...
# [ 0.9663691  -1.975       0.47660035  4.35471271 -1.975     ]
# Processing Fe ...
# [ 0.81636803 -2.075       0.47394505  2.66887479 -2.075     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 174
#
# Processing snapshot 175 ...
#
# Processing C ...
# [ 0.66273569 -1.325       0.27791624  3.07091693 -1.275     ]
# Processing N ...
# [ 0.69359625 -1.525       0.2923791   2.85729165 -1.425     ]
# Processing O ...
# [ 0.82586564 -1.575       0.47473942  4.54309829 -1.575     ]
# Processing Ne ...
# [ 0.91001674 -1.475       0.47465956  5.21314048 -1.475     ]
# Processing Mg ...
# [ 0.82276232 -1.725       0.46794762  5.33891079 -1.725     ]
# Processing Si ...
# [ 0.78691512 -1.725       0.45028556  3.73559128 -1.725     ]
# Processing S ...
# [ 0.95963726 -1.675       0.45770363  5.37128988 -1.675     ]
# Processing Ca ...
# [ 0.90226736 -1.975       0.45373245  4.76917149 -1.975     ]
# Processing Fe ...
# [ 0.91262412 -1.975       0.43381382  2.57461876 -1.925     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 175
#
# Processing snapshot 176 ...
#
# Processing C ...
# [ 0.57787031 -1.325       0.24643236  3.40678537 -1.175     ]
# Processing N ...
# [ 0.63616509 -1.525       0.24979341  3.02385702 -1.325     ]
# Processing O ...
# [ 0.95866596 -1.525       0.48994575  5.63306524 -1.525     ]
# Processing Ne ...
# [ 0.83248021 -1.525       0.49012356  4.07333877 -1.525     ]
# Processing Mg ...
# [ 0.83745586 -1.775       0.48973069  4.73684759 -1.725     ]
# Processing Si ...
# [ 0.78333449 -1.725       0.46157491  3.87714547 -1.725     ]
# Processing S ...
# [ 0.97196614 -1.675       0.46779843  5.73078245 -1.675     ]
# Processing Ca ...
# [ 0.74979668 -2.075       0.45930618  3.30727084 -2.075     ]
# Processing Fe ...
# [ 0.8786646  -1.975       0.43935386  3.74468191 -1.975     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 176
#
# Processing snapshot 177 ...
#
# Processing C ...
# [ 0.58799936 -1.325       0.23923141  3.38248873 -1.125     ]
# Processing N ...
# [ 0.61042386 -1.525       0.24542073  3.34772854 -1.275     ]
# Processing O ...
# [ 0.6881291  -1.625       0.40913078  3.81016947 -1.625     ]
# Processing Ne ...
# [ 0.65000745 -1.575       0.41447099  3.62033456 -1.575     ]
# Processing Mg ...
# [ 0.64218222 -1.825       0.41101234  3.41437055 -1.825     ]
# Processing Si ...
# [ 0.80891523 -1.675       0.38972852  7.54077525 -1.525     ]
# Processing S ...
# [ 0.78596105 -1.725       0.39039016  4.65352793 -1.725     ]
# Processing Ca ...
# [ 0.71874056 -2.075       0.38410108  4.62307765 -1.975     ]
# Processing Fe ...
# [ 0.74807338 -2.025       0.35739649  3.30539462 -2.025     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 177
#
# Processing snapshot 178 ...
#
# Processing C ...
# [ 0.58695556 -1.325       0.23373703  4.16026403 -1.275     ]
# Processing N ...
# [ 0.5867893  -1.525       0.24873525  3.13985141 -1.275     ]
# Processing O ...
# [ 0.62067382 -1.575       0.3342994   5.101961   -1.575     ]
# Processing Ne ...
# [ 0.68177442 -1.475       0.33558304  6.1265092  -1.475     ]
# Processing Mg ...
# [ 0.65416689 -1.725       0.32974051  5.77706944 -1.725     ]
# Processing Si ...
# [ 0.59903135 -1.725       0.31205823  5.2307471  -1.675     ]
# Processing S ...
# [ 0.68572733 -1.725       0.318923    6.88741355 -1.625     ]
# Processing Ca ...
# [ 0.63207137 -2.025       0.31247502  5.32935161 -1.975     ]
# Processing Fe ...
# [ 0.75752756 -1.975       0.32110331  3.36048058 -1.925     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 178
#
# Processing snapshot 179 ...
#
# Processing C ...
# [ 0.5288808  -1.325       0.21561341  4.4983848  -1.225     ]
# Processing N ...
# [ 0.6641457  -1.475       0.26100824  3.97470829 -1.425     ]
# Processing O ...
# [ 0.62211401 -1.575       0.32233937  5.16230325 -1.575     ]
# Processing Ne ...
# [ 0.5901356  -1.525       0.32162136  4.81434116 -1.525     ]
# Processing Mg ...
# [ 0.5747359  -1.775       0.31925969  4.52254601 -1.775     ]
# Processing Si ...
# [ 0.54319633 -1.725       0.28497497  4.40622008 -1.725     ]
# Processing S ...
# [ 0.56437356 -1.775       0.28390088  5.07678109 -1.725     ]
# Processing Ca ...
# [ 0.60126634 -2.025       0.28450247  5.26757443 -1.975     ]
# Processing Fe ...
# [ 0.55617175 -2.025       0.26012014  3.40803582 -2.025     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 179
#
# Processing snapshot 180 ...
#
# Processing C ...
# [ 0.65607184 -1.275       0.26061703  5.05102794 -1.225     ]
# Processing N ...
# [ 0.67545278 -1.475       0.27403412  4.46220584 -1.425     ]
# Processing O ...
# [ 0.57147496 -1.625       0.31956731  5.0125343  -1.575     ]
# Processing Ne ...
# [ 0.59968003 -1.525       0.32048277  6.35546991 -1.475     ]
# Processing Mg ...
# [ 0.58077011 -1.775       0.3137593   5.91098857 -1.725     ]
# Processing Si ...
# [ 0.53559968 -1.725       0.28259213  4.49255195 -1.725     ]
# Processing S ...
# [ 0.56430456 -1.775       0.28160769  5.11061806 -1.725     ]
# Processing Ca ...
# [ 0.69580347 -1.975       0.30435638  5.54253414 -1.975     ]
# Processing Fe ...
# [ 0.55343186 -2.025       0.24967292  3.3401623  -2.025     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 180
#
# Processing snapshot 181 ...
#
# Processing C ...
# [ 0.47910298 -1.375       0.20610885  4.48288127 -1.275     ]
# Processing N ...
# [ 0.58519237 -1.525       0.25812705  4.54944883 -1.425     ]
# Processing O ...
# [ 0.55971153 -1.625       0.31466836  5.34237974 -1.575     ]
# Processing Ne ...
# [ 0.6045072  -1.525       0.31347834  5.06664791 -1.525     ]
# Processing Mg ...
# [ 0.58678718 -1.775       0.31029393  6.22295783 -1.725     ]
# Processing Si ...
# [ 0.5525584  -1.725       0.27915298  6.98649338 -1.525     ]
# Processing S ...
# [ 0.54359642 -1.775       0.27468421  7.13962114 -1.625     ]
# Processing Ca ...
# [ 0.51458008 -2.075       0.27011602  5.5394346  -1.975     ]
# Processing Fe ...
# [ 0.55972633 -2.025       0.24509485  3.89053389 -1.975     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 181
#
# Processing snapshot 182 ...
#
# Processing C ...
# [ 0.69696186 -1.275       0.28472987  5.02624932 -1.275     ]
# Processing N ...
# [ 0.72578113 -1.475       0.30938863  4.6009019  -1.425     ]
# Processing O ...
# [ 0.58811205 -1.575       0.29449197  5.84530809 -1.575     ]
# Processing Ne ...
# [ 0.5673625  -1.525       0.29164855  5.34948402 -1.525     ]
# Processing Mg ...
# [ 0.54938621 -1.775       0.29195308  6.72754026 -1.725     ]
# Processing Si ...
# [ 0.52700814 -1.725       0.26669608  4.77709016 -1.725     ]
# Processing S ...
# [ 0.53124376 -1.775       0.26228679  5.65432517 -1.725     ]
# Processing Ca ...
# [ 0.48226375 -2.075       0.25169572  4.85797455 -2.025     ]
# Processing Fe ...
# [ 0.52651305 -2.025       0.22872137  4.27920768 -1.975     ]
# Completed rendering for C
# ...
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 586
#
# Processing snapshot 587 ...
#
# Processing C ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  3.15186368e+01
#  -8.75000000e-01]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.70723156e+01
#  -1.12500000e+00]
# Processing O ...
# [ 2.50662827e-10 -9.75000000e-01  1.00000000e-10  3.93203912e+01
#  -9.25000000e-01]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.36720472e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.22337511e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11171464 -1.075       0.04477226 30.02595107 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.09595126e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 2.50662827e-10 -1.37500000e+00  1.00000000e-10  2.68002911e+01
#  -1.32500000e+00]
# Processing Fe ...
# [ 0.14627376 -1.225       0.05700719 12.93894848 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 587
#
# Processing snapshot 588 ...
#
# Processing C ...
# [ 0.11075081 -0.925       0.04447155 28.65221721 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.66040187e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.10873531 -0.975       0.04362485 40.96836296 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.54284951e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.25657817e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11765601 -1.075       0.04711074 31.25782969 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.15845895e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 2.50662827e-10 -1.37500000e+00  1.00000000e-10  2.60624542e+01
#  -1.32500000e+00]
# Processing Fe ...
# [ 0.15566002 -1.225       0.06023741 12.90201844 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 588
#
# Processing snapshot 589 ...
#
# Processing C ...
# [ 0.11261703 -0.925       0.04528352 29.82126332 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.62890660e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.10827117 -0.975       0.04339592 39.6202194  -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.36494690e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.49709273e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11900988 -1.075       0.04746872 28.85359476 -1.075     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.01367206e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11017696 -1.375       0.04417696 26.61428758 -1.325     ]
# Processing Fe ...
# [ 0.15196451 -1.225       0.05891826 11.96978662 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 589
#
# Processing snapshot 590 ...
#
# Processing C ...
# [ 0.11375576 -0.925       0.04580129 32.12891283 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.64743755e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.1094856  -0.975       0.04397458 39.01560962 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.24829118e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.24575817e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11846042 -1.075       0.04743095 28.43621185 -1.075     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  2.81057087e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11314631 -1.375       0.04543419 24.04347828 -1.375     ]
# Processing Fe ...
# [ 0.15544018 -1.225       0.06035976 12.00250879 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 590
#
# Processing snapshot 591 ...
#
# Processing C ...
# [ 0.11258254 -0.925       0.04525777 32.19432674 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.72589871e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.10891917 -0.975       0.0437315  41.04389038 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.10232233e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.17568614e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11836105 -1.075       0.04735458 28.10792747 -1.075     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  2.85139227e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11270887 -1.375       0.04523141 24.31139322 -1.375     ]
# Processing Fe ...
# [ 0.15783629 -1.225       0.061021   12.00225399 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 591
#
# Processing snapshot 592 ...
#
# Processing C ...
# [ 0.11626603 -0.925       0.04667242 31.48468918 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.70768368e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.11246119 -0.975       0.04510473 39.59760979 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  3.94965860e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.06581201e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.12142312 -1.075       0.04848532 29.56311527 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  2.86949308e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11401044 -1.375       0.04574068 24.56074271 -1.375     ]
# Processing Fe ...
# [ 0.16169103 -1.225       0.06207399 12.20699779 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 592
#
# Processing snapshot 593 ...
#
# Processing C ...
# [ 0.11494757 -0.925       0.04627377 32.07594004 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.70501887e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.11089099 -0.975       0.04448995 40.7172282  -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  3.84921117e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.06087656e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.12087377 -1.075       0.04829261 27.57717465 -1.075     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  2.88890398e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11367243 -1.375       0.04562946 24.27212754 -1.375     ]
# Processing Fe ...
# [ 0.16411336 -1.225       0.06237973 11.97125273 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 593
#
# Processing snapshot 594 ...
#
# Processing C ...
# [ 0.11370478 -0.925       0.04587183 32.01397567 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.74615033e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.11122619 -0.975       0.04461304 39.71177925 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.10516368e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.19246329e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.12078211 -1.075       0.04819645 26.55821927 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.01850189e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11456383 -1.375       0.04590292 24.98221188 -1.375     ]
# Processing Fe ...
# [ 0.16032588 -1.225       0.06146799 11.50203991 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 594
#
# Processing snapshot 595 ...
#
# Processing C ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  3.23995407e+01
#  -8.75000000e-01]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.90681122e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.10938427 -0.975       0.04395023 38.20176943 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.01805948e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.14462655e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11870946 -1.075       0.04752453 25.17012703 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  2.99211584e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11202081 -1.375       0.04498966 25.44535541 -1.375     ]
# Processing Fe ...
# [ 0.15975236 -1.225       0.06139098 11.93604949 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 595
#
# Processing snapshot 596 ...
#
# Processing C ...
# [ 0.11335227 -0.925       0.04560168 33.06927005 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.90926580e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.10981271 -0.975       0.04412489 36.89966095 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.04707503e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.08139546e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11950774 -1.075       0.04775365 25.78626854 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  2.94337296e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11188202 -1.375       0.04490152 25.64512873 -1.375     ]
# Processing Fe ...
# [ 0.15923557 -1.225       0.06090428 12.48766927 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 596
#
# Processing snapshot 597 ...
#
# Processing C ...
# [ 0.1125085  -0.925       0.04516808 35.09560087 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.76628656e+01
#  -1.12500000e+00]
# Processing O ...
# [ 2.50662827e-10 -9.75000000e-01  1.00000000e-10  3.65871698e+01
#  -9.25000000e-01]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.07890488e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.12851246e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11948783 -1.075       0.04764125 29.43456142 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.08658564e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.10976826 -1.375       0.04406713 25.90577389 -1.375     ]
# Processing Fe ...
# [ 0.15775589 -1.225       0.06041796 12.55490034 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 597
#
# Processing snapshot 598 ...
#
# Processing C ...
# [ 0.1127665  -0.925       0.04527903 34.54528866 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.90465924e+01
#  -1.12500000e+00]
# Processing O ...
# [ 2.50662827e-10 -9.75000000e-01  1.00000000e-10  3.68362654e+01
#  -9.25000000e-01]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.11577031e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.05038926e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.12028503 -1.075       0.0479018  30.84866431 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.06825458e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.10954826 -1.375       0.04395089 26.85781815 -1.375     ]
# Processing Fe ...
# [ 0.15340524 -1.225       0.05926681 13.65011011 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 598
#
# Processing snapshot 599 ...
#
# Processing C ...
# [ 0.1115532  -0.925       0.04481773 33.48695633 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.89087728e+01
#  -1.12500000e+00]
# Processing O ...
# [ 0.10899866 -0.975       0.04376093 36.43428919 -0.925     ]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.13911702e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  3.91411149e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.12049885 -1.075       0.04801638 33.25085681 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.14174293e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 0.11004699 -1.375       0.04416085 26.02068462 -1.375     ]
# Processing Fe ...
# [ 0.151488   -1.225       0.05881007 13.76677651 -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 599
#
# Processing snapshot 600 ...
#
# Processing C ...
# [ 0.11072559 -0.925       0.04451358 34.37865961 -0.875     ]
# Processing N ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  2.96171604e+01
#  -1.12500000e+00]
# Processing O ...
# [ 2.50662827e-10 -9.75000000e-01  1.00000000e-10  3.81609388e+01
#  -9.25000000e-01]
# Processing Ne ...
# [ 2.50662827e-10 -9.25000000e-01  1.00000000e-10  4.24333422e+01
#  -8.75000000e-01]
# Processing Mg ...
# [ 2.50662827e-10 -1.17500000e+00  1.00000000e-10  4.00652063e+01
#  -1.12500000e+00]
# Processing Si ...
# [ 0.11777759 -1.075       0.04703198 33.39789249 -1.025     ]
# Processing S ...
# [ 2.50662827e-10 -1.12500000e+00  1.00000000e-10  3.17815295e+01
#  -1.07500000e+00]
# Processing Ca ...
# [ 2.50662827e-10 -1.37500000e+00  1.00000000e-10  2.69055572e+01
#  -1.32500000e+00]
# Processing Fe ...
# [ 0.15221106 -1.225       0.05860917 13.6141051  -1.175     ]
# Completed rendering for C
# Completed rendering for N
# Completed rendering for O
# Completed rendering for Ne
# Completed rendering for Mg
# Completed rendering for Si
# Completed rendering for S
# Completed rendering for Ca
# Completed rendering for Fe
#
# Completed fitting for snapshot 600

# %%
for m in metals:
    param_df_init = pd.read_csv(spath_metals[m] + 'data/fit/fit_{}_params.csv'.format(m))
    param_dict_append = {'A': As[m], 'mu': mus[m], 'sigma': sigmas[m], 
                  'alpha': alphas[m], 'z_T': z_Ts[m]}
    param_df_append = pd.DataFrame(param_dict_append)
    param_df = pd.concat([param_df_init, param_df_append], axis = 1)
    param_df.to_csv(spath_metals[m] + 'data/fit/fit_{}_params.csv'.format(m), index = False)
